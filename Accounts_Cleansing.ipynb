# %% [markdown]
# # Cleansing Sallie Mae Accounts Table

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('/Users/stewarta/Documents/DATA/USA/sallie/accounts_master.csv', delimiter = ';')
df.head()
# Out:
#    Dir_ID   EOS_Acct  Seed_Acct   Client_Acct Client_ID   List_Date  \
# 0    11.0  8630398.0  8630398.0  5.852500e+15    SLMFDF  02/17/2017
# 1    11.0  8630399.0  8630399.0  5.852500e+15    SLMFDF  02/17/2017
# 2    11.0  8630400.0  8630400.0  5.852500e+15    SLMFDF  02/17/2017
# 3    11.0  8630401.0  8630400.0  5.852500e+15    SLMFDF  02/17/2017
# 4    11.0  8630402.0  8630402.0  5.852500e+15    SLMFDF  02/17/2017
#
#   FACS_Load_Date Disposition   Dept  Initial_Balance     ...       \
# 0     02/17/2017        3EMP  321.0          9692.68     ...
# 1     02/17/2017        9999    0.0         12942.49     ...
# 2     02/17/2017        3GPH  321.0          5785.62     ...
# 3     02/17/2017        3GPH  321.0           468.88     ...
# 4     02/17/2017        3EMP  317.0          9394.19     ...
#
#             City State    Zip Experian_Score  Sungard_Score Collector_ID  \
# 0      LAS VEGAS    NV  89129            0.0             B1          SMP
# ...

# %%
# how much data is missing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11455 entries, 0 to 11454
# Data columns (total 21 columns):
# Dir_ID             9632 non-null float64
# EOS_Acct           9632 non-null float64
# Seed_Acct          9632 non-null float64
# Client_Acct        9632 non-null float64
# Client_ID          9632 non-null object
# List_Date          9632 non-null object
# FACS_Load_Date     9632 non-null object
# Disposition        9632 non-null object
# Dept               9632 non-null float64
# Initial_Balance    9632 non-null float64
# Account_Balance    9632 non-null float64
# City               9632 non-null object
# State              9632 non-null object
# Zip                9632 non-null object
# Experian_Score     9632 non-null float64
# Sungard_Score      9575 non-null object
# Collector_ID       9632 non-null object
# Disp_Chg_Date      9630 non-null object
# Service_Date       7604 non-null object
# HSG_Proscore       9632 non-null float64
# ...

# %%
# examine the missingness across columns
msno.matrix(df)

# %%
# drop column
df.drop('Service_Date', axis=1, inplace=True)
msno.matrix(df)

# %%
df.tail()
# Out:
#        Dir_ID   EOS_Acct  Seed_Acct   Client_Acct Client_ID   List_Date  \
# 11450     NaN        NaN        NaN           NaN       NaN         NaN
# 11451    11.0  9437600.0  9437600.0  5.852500e+15    SLMFDF  06/15/2017
# 11452     NaN        NaN        NaN           NaN       NaN         NaN
# 11453    11.0  9437601.0  9437601.0  5.852500e+15    SLMFDF  06/15/2017
# 11454     NaN        NaN        NaN           NaN       NaN         NaN
#
#       FACS_Load_Date Disposition   Dept  Initial_Balance  Account_Balance  \
# 11450            NaN         NaN    NaN              NaN              NaN
# 11451     06/15/2017        3GPH  321.0         22542.15         22830.42
# 11452            NaN         NaN    NaN              NaN              NaN
# 11453     06/15/2017        3PDC  317.0         12668.30         12796.48
# 11454            NaN         NaN    NaN              NaN              NaN
#
#                      City State    Zip  Experian_Score Sungard_Score  \
# ...

# %%
df.drop(columns='Unnamed: 20', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11455 entries, 0 to 11454
# Data columns (total 19 columns):
# Dir_ID             9632 non-null float64
# EOS_Acct           9632 non-null float64
# Seed_Acct          9632 non-null float64
# Client_Acct        9632 non-null float64
# Client_ID          9632 non-null object
# List_Date          9632 non-null object
# FACS_Load_Date     9632 non-null object
# Disposition        9632 non-null object
# Dept               9632 non-null float64
# Initial_Balance    9632 non-null float64
# Account_Balance    9632 non-null float64
# City               9632 non-null object
# State              9632 non-null object
# Zip                9632 non-null object
# Experian_Score     9632 non-null float64
# Sungard_Score      9575 non-null object
# Collector_ID       9632 non-null object
# Disp_Chg_Date      9630 non-null object
# HSG_Proscore       9632 non-null float64
# dtypes: float64(9), object(10)
# memory usage: 1.7+ MB

# %%
msno.matrix(df)

# %%
df.isnull().sum()
# Out:
# Dir_ID             1823
# EOS_Acct           1823
# Seed_Acct          1823
# Client_Acct        1823
# Client_ID          1823
# List_Date          1823
# FACS_Load_Date     1823
# Disposition        1823
# Dept               1823
# Initial_Balance    1823
# Account_Balance    1823
# City               1823
# State              1823
# Zip                1823
# Experian_Score     1823
# Sungard_Score      1880
# Collector_ID       1823
# Disp_Chg_Date      1825
# HSG_Proscore       1823
# dtype: int64

# %%
df.dropna(inplace=True)
df.head()
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9573 entries, 0 to 11453
# Data columns (total 19 columns):
# Dir_ID             9573 non-null float64
# EOS_Acct           9573 non-null float64
# Seed_Acct          9573 non-null float64
# Client_Acct        9573 non-null float64
# Client_ID          9573 non-null object
# List_Date          9573 non-null object
# FACS_Load_Date     9573 non-null object
# Disposition        9573 non-null object
# Dept               9573 non-null float64
# Initial_Balance    9573 non-null float64
# Account_Balance    9573 non-null float64
# City               9573 non-null object
# State              9573 non-null object
# Zip                9573 non-null object
# Experian_Score     9573 non-null float64
# Sungard_Score      9573 non-null object
# Collector_ID       9573 non-null object
# Disp_Chg_Date      9573 non-null object
# HSG_Proscore       9573 non-null float64
# dtypes: float64(9), object(10)
# memory usage: 1.5+ MB
# ...

# %%
msno.matrix(df)
