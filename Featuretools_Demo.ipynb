# %% [markdown]
# Explore use of Feature Tools to generate features

# %%
# ensure user defined modules are on the python path
import featuretools as ft
import os
import sys
import pandas as pd
import numpy as np

# %%
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
#print(sys.path)
from salliemae.data.experian import subset_installments, clean_account_master

# %%
# load tradelined data 
tradeline_df = pd.read_csv('/Users/stewarta/Documents/DATA/USA/sallie/tradelines.csv',  sep=';',low_memory= False, na_values = '""')
tradeline_df.head()
# Out:
#    Dir_ID  EOS_Acct  Subject_ID  Tradeline_Index Responsible Tradeline_Type  \
# 0      11   8155318       41841                5           I              I
# 1      11   8155318       41841                6           I              I
# 2      11   8155318       41841                7           I              I
# 3      11   8155318       41841                8           I              I
# 4      11   8155318       41841                9           I              I
#
#   Date_Reported  LKTRRDTI_Data  First_Reported_Date  LKTRFDTI_Data  \
# 0    08/14/2016        8142016                  NaN            NaN
# 1    08/14/2016        8142016                  NaN            NaN
# 2    08/14/2016        8142016                  NaN            NaN
# 3    08/14/2016        8142016                  NaN            NaN
# 4    08/14/2016        8142016                  NaN            NaN
#
#        ...      Orgnl_Grantor_Name  Orgnl_Grantor_Biz Data_Source  \
# 0      ...                     NaN                NaN         NaN
# 1      ...                     NaN                NaN         NaN
# 2      ...                     NaN                NaN         NaN
# 3      ...                     NaN                NaN         NaN
# 4      ...                     NaN                NaN         NaN
#
#    Indicator_Code_1  Indicator_Code_2 Indicator_Code_3 Indicator_Code_4  \
# 0                 N               NaN              NaN              NaN
# 1                 N               NaN              NaN              NaN
# 2                 N               NaN              NaN              NaN
# 3                 N               NaN              NaN              NaN
# 4                 N               NaN              NaN              NaN
#
#   Trigger_ID Subject_Type  Unnamed: 104
# 0          0          B\r           NaN
# 1          0          B\r           NaN
# 2          0          B\r           NaN
# 3          0          B\r           NaN
# 4          0          B\r           NaN
#
# [5 rows x 105 columns]

# %%
tradeline_df = subset_installments(tradeline_df)

# %%
# remove columns that will not be used in the featuretools
non_featuretools = [ 'Subject_ID','Payment_History', 'Tradeline_Index']
tradeline_df.drop(non_featuretools, axis=1, inplace=True)
tradeline_df['EOS_Acct'] =  tradeline_df['EOS_Acct'].astype('int64')
tradeline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250916 entries, 0 to 420115
# Data columns (total 19 columns):
# EOS_Acct               250916 non-null int64
# Responsible            250916 non-null object
# Tradeline_Type         250916 non-null object
# Date_Reported          250916 non-null object
# Subscriber_Code        250916 non-null int64
# Industry_Type          250916 non-null object
# Tradeline_Usage        250916 non-null object
# Date_Opened            250916 non-null object
# Trade_Ending_Cd        250916 non-null object
# Term_Duration          250916 non-null int64
# Manner_Of_Pmt_Dte      250916 non-null object
# Manner_Of_Payment      250916 non-null object
# History_Reviewed       250916 non-null float64
# Delinquent_Payments    250916 non-null float64
# Late_30_Days           250916 non-null float64
# Late_60_Days           250916 non-null float64
# Late_90_Days           250916 non-null float64
# Indicator_Code_1       250916 non-null object
# Subject_Type           250916 non-null object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 38.3+ MB

# %%
tradeline_df.head()
# Out:
#    EOS_Acct Responsible Tradeline_Type Date_Reported  Subscriber_Code  \
# 0   8155318           I              I    08/14/2016          1906328
# 1   8155318           I              I    08/14/2016          1906328
# 2   8155318           I              I    08/14/2016          1906328
# 3   8155318           I              I    08/14/2016          1906328
# 4   8155318           I              I    08/14/2016          1906328
#
#   Industry_Type Tradeline_Usage Date_Opened Trade_Ending_Cd  Term_Duration  \
# 0            VF              12  07/19/2011               C             36
# 1            VF              12  05/14/2012               C             36
# 2            VF              12  09/02/2010               C             36
# 3            VF              12  05/24/2013               C             36
# 4            VF              12  12/06/2012               C             36
#
#   Manner_Of_Pmt_Dte Manner_Of_Payment  History_Reviewed  Delinquent_Payments  \
# 0        08/01/2015                93              13.0                 12.0
# 1        08/01/2015                93              13.0                 12.0
# 2        08/01/2015                93              13.0                 12.0
# 3        08/01/2015                93              13.0                 12.0
# 4        08/01/2015                93              13.0                 12.0
#
#    Late_30_Days  Late_60_Days  Late_90_Days Indicator_Code_1 Subject_Type
# 0           0.0           0.0           0.0                N          B\r
# 1           0.0           0.0           0.0                N          B\r
# 2           0.0           0.0           0.0                N          B\r
# 3           0.0           0.0           0.0                N          B\r
# 4           0.0           0.0           0.0                N          B\r

# %%
# remove newlines characters
tradeline_df['Subject_Type'] = [''.join(c.split()) for c in tradeline_df['Subject_Type'].astype(str)]

# %%
tradeline_df.head()
# Out:
#    EOS_Acct Responsible Tradeline_Type Date_Reported  Subscriber_Code  \
# 0   8155318           I              I    08/14/2016          1906328
# 1   8155318           I              I    08/14/2016          1906328
# 2   8155318           I              I    08/14/2016          1906328
# 3   8155318           I              I    08/14/2016          1906328
# 4   8155318           I              I    08/14/2016          1906328
#
#   Industry_Type Tradeline_Usage Date_Opened Trade_Ending_Cd  Term_Duration  \
# 0            VF              12  07/19/2011               C             36
# 1            VF              12  05/14/2012               C             36
# 2            VF              12  09/02/2010               C             36
# 3            VF              12  05/24/2013               C             36
# 4            VF              12  12/06/2012               C             36
#
#   Manner_Of_Pmt_Dte Manner_Of_Payment  History_Reviewed  Delinquent_Payments  \
# 0        08/01/2015                93              13.0                 12.0
# 1        08/01/2015                93              13.0                 12.0
# 2        08/01/2015                93              13.0                 12.0
# 3        08/01/2015                93              13.0                 12.0
# 4        08/01/2015                93              13.0                 12.0
#
#    Late_30_Days  Late_60_Days  Late_90_Days Indicator_Code_1 Subject_Type
# 0           0.0           0.0           0.0                N            B
# 1           0.0           0.0           0.0                N            B
# 2           0.0           0.0           0.0                N            B
# 3           0.0           0.0           0.0                N            B
# 4           0.0           0.0           0.0                N            B

# %%
# insert index on tradelines table
tradeline_df.insert(loc=0, column='tradeline_idx', value=range(0,len(tradeline_df)))

# %%
tradeline_df.head()
# Out:
#    tradeline_idx  EOS_Acct Responsible Tradeline_Type Date_Reported  \
# 0              0   8155318           I              I    08/14/2016
# 1              1   8155318           I              I    08/14/2016
# 2              2   8155318           I              I    08/14/2016
# 3              3   8155318           I              I    08/14/2016
# 4              4   8155318           I              I    08/14/2016
#
#    Subscriber_Code Industry_Type Tradeline_Usage Date_Opened Trade_Ending_Cd  \
# 0          1906328            VF              12  07/19/2011               C
# 1          1906328            VF              12  05/14/2012               C
# 2          1906328            VF              12  09/02/2010               C
# 3          1906328            VF              12  05/24/2013               C
# 4          1906328            VF              12  12/06/2012               C
#
#    Term_Duration Manner_Of_Pmt_Dte Manner_Of_Payment  History_Reviewed  \
# 0             36        08/01/2015                93              13.0
# 1             36        08/01/2015                93              13.0
# 2             36        08/01/2015                93              13.0
# 3             36        08/01/2015                93              13.0
# 4             36        08/01/2015                93              13.0
#
#    Delinquent_Payments  Late_30_Days  Late_60_Days  Late_90_Days  \
# 0                 12.0           0.0           0.0           0.0
# 1                 12.0           0.0           0.0           0.0
# 2                 12.0           0.0           0.0           0.0
# 3                 12.0           0.0           0.0           0.0
# 4                 12.0           0.0           0.0           0.0
#
#   Indicator_Code_1 Subject_Type
# 0                N            B
# 1                N            B
# 2                N            B
# 3                N            B
# 4                N            B

# %%
# Create entity Set
es = ft.EntitySet(id='tx')

# %%
es = es.entity_from_dataframe(dataframe=tradeline_df,
                         entity_id='tradelines',
                         index='tradeline_idx',
                         variable_types={#"EOS_Acct": ft.variable_types.Id, 
                                        "Responsible": ft.variable_types.Categorical, 
                                        "Tradeline_Type": ft.variable_types.Categorical,
                                        "Date_Reported": ft.variable_types.Datetime,
                                        "Subscriber_Code": ft.variable_types.Categorical,
                                        "Industry_Type": ft.variable_types.Categorical,
                                        "Tradeline_Usage": ft.variable_types.Categorical,
                                        "Date_Opened": ft.variable_types.Datetime,
                                        "Trade_Ending_Cd": ft.variable_types.Categorical,
                                        "Term_Duration": ft.variable_types.Numeric,
                                        "Manner_Of_Pmt_Dte": ft.variable_types.Datetime,
                                        "Manner_Of_Payment": ft.variable_types.Categorical,
                                        "History_Reviewed": ft.variable_types.Numeric,
                                        "Delinquent_Payments": ft.variable_types.Numeric,
                                        "Late_30_Days": ft.variable_types.Numeric,
                                        "Late_60_Days": ft.variable_types.Numeric,
                                        "Late_90_Days": ft.variable_types.Numeric,
                                        "Indicator_Code_1": ft.variable_types.Categorical,
                                        "Subject_Type": ft.variable_types.Categorical})

# %%
es['tradelines'].variables
# Out:
# [<Variable: tradeline_idx (dtype = index)>,
#  <Variable: EOS_Acct (dtype = numeric)>,
#  <Variable: Responsible (dtype = categorical)>,
#  <Variable: Tradeline_Type (dtype = categorical)>,
#  <Variable: Date_Reported (dtype: datetime, format: None)>,
#  <Variable: Subscriber_Code (dtype = categorical)>,
#  <Variable: Industry_Type (dtype = categorical)>,
#  <Variable: Tradeline_Usage (dtype = categorical)>,
#  <Variable: Date_Opened (dtype: datetime, format: None)>,
#  <Variable: Trade_Ending_Cd (dtype = categorical)>,
#  <Variable: Term_Duration (dtype = numeric)>,
#  <Variable: Manner_Of_Pmt_Dte (dtype: datetime, format: None)>,
#  <Variable: Manner_Of_Payment (dtype = categorical)>,
#  <Variable: History_Reviewed (dtype = numeric)>,
#  <Variable: Delinquent_Payments (dtype = numeric)>,
#  <Variable: Late_30_Days (dtype = numeric)>,
#  <Variable: Late_60_Days (dtype = numeric)>,
#  <Variable: Late_90_Days (dtype = numeric)>,
#  <Variable: Indicator_Code_1 (dtype = categorical)>,
#  <Variable: Subject_Type (dtype = categorical)>]

# %%
# load accounts table
dtypes = {'Client_Acct': 'str'}
parse_dates = ['List_Date', 'Disp_Chg_Date']
df = pd.read_csv('/Users/stewarta/Documents/DATA/USA/sallie/accounts_master.csv', delimiter = ';', dtype=dtypes, parse_dates=parse_dates)
df.head()
# Out:
#    Dir_ID   EOS_Acct  Seed_Acct       Client_Acct Client_ID  List_Date  \
# 0    11.0  8630398.0  8630398.0  5852500000195755    SLMFDF 2017-02-17
# 1    11.0  8630399.0  8630399.0  5852500007564854    SLMFDF 2017-02-17
# 2    11.0  8630400.0  8630400.0  5852500007571503    SLMFDF 2017-02-17
# 3    11.0  8630401.0  8630400.0  5852500007572162    SLMFDF 2017-02-17
# 4    11.0  8630402.0  8630402.0  5852500007573376    SLMFDF 2017-02-17
#
#   FACS_Load_Date Disposition   Dept  Initial_Balance     ...       \
# 0     02/17/2017        3EMP  321.0          9692.68     ...
# 1     02/17/2017        9999    0.0         12942.49     ...
# 2     02/17/2017        3GPH  321.0          5785.62     ...
# 3     02/17/2017        3GPH  321.0           468.88     ...
# 4     02/17/2017        3EMP  317.0          9394.19     ...
#
#             City State    Zip Experian_Score  Sungard_Score Collector_ID  \
# 0      LAS VEGAS    NV  89129            0.0             B1          SMP
# 1     SAINT PAUL    MN  55106            0.0             A3            0
# 2    ALBUQUERQUE    NM  87114            0.0             B3          SMP
# 3    ALBUQUERQUE    NM  87114            0.0             C2          SMP
# 4  COLORADO SPGS    CO  80903            0.0             B1          UE2
#
#   Disp_Chg_Date Service_Date HSG_Proscore  Unnamed: 20
# 0    2017-05-08   02/23/2011          4.0          NaN
# 1    2017-04-06          NaN          0.0          NaN
# 2    2017-07-21   05/28/2013          4.0          NaN
# 3    2017-07-21   05/28/2013          0.0          NaN
# 4    2017-07-03   05/24/2013          0.0          NaN
#
# [5 rows x 21 columns]

# %%
accounts_df = clean_account_master(df)

# %%
accounts_df.head()
accounts_non_featuretools = [ 'Dir_ID','Seed_Acct', 'Client_Acct','City', 'State', 'Zip' ]
accounts_df = accounts_df.drop(accounts_non_featuretools, axis=1, inplace=False)
accounts_df['EOS_Acct'] =  accounts_df['EOS_Acct'].astype('int64')
accounts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9573 entries, 0 to 11453
# Data columns (total 13 columns):
# EOS_Acct           9573 non-null int64
# Client_ID          9573 non-null object
# List_Date          9573 non-null datetime64[ns]
# FACS_Load_Date     9573 non-null object
# Disposition        9573 non-null object
# Dept               9573 non-null float64
# Initial_Balance    9573 non-null float64
# Account_Balance    9573 non-null float64
# Experian_Score     9573 non-null float64
# Sungard_Score      9573 non-null object
# Collector_ID       9573 non-null object
# Disp_Chg_Date      9573 non-null datetime64[ns]
# HSG_Proscore       9573 non-null float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(5)
# memory usage: 1.0+ MB

# %%
## '%m/%d/%Y'
es = es.entity_from_dataframe(dataframe=accounts_df,
                         entity_id='accounts',
                         index='EOS_Acct',
                         variable_types={#"EOS_Acct": ft.variable_types.Index, 
                                         "Client_ID": ft.variable_types.Categorical, 
                                        "List_Date": ft.variable_types.Datetime,
                                        "FACS_Load_Date": ft.variable_types.Datetime,
                                        "Disposition": ft.variable_types.Categorical,
                                        "Dept": ft.variable_types.Categorical,
                                        "Initial_Balance": ft.variable_types.Numeric,
                                        "Account_Balance": ft.variable_types.Categorical,
                                        "Experian_Score": ft.variable_types.Categorical,
                                        "Sungard_Score": ft.variable_types.Categorical,
                                        "Collector_ID": ft.variable_types.Categorical,
                                        "Disp_Chg_Date": ft.variable_types.Categorical,
                                        "HSG_Proscore": ft.variable_types.Categorical})
es
# Out:
# Entityset: tx
#   Entities:
#     tradelines [Rows: 250916, Columns: 20]
#     accounts [Rows: 9573, Columns: 13]
#   Relationships:
#     No relationships

# %%
es['accounts'].variables
# Out:
# [<Variable: EOS_Acct (dtype = index)>,
#  <Variable: Client_ID (dtype = categorical)>,
#  <Variable: List_Date (dtype: datetime, format: None)>,
#  <Variable: FACS_Load_Date (dtype: datetime, format: None)>,
#  <Variable: Disposition (dtype = categorical)>,
#  <Variable: Dept (dtype = categorical)>,
#  <Variable: Initial_Balance (dtype = numeric)>,
#  <Variable: Account_Balance (dtype = categorical)>,
#  <Variable: Experian_Score (dtype = categorical)>,
#  <Variable: Sungard_Score (dtype = categorical)>,
#  <Variable: Collector_ID (dtype = categorical)>,
#  <Variable: Disp_Chg_Date (dtype = categorical)>,
#  <Variable: HSG_Proscore (dtype = categorical)>]

# %%
# create a new relationship
new_relationship = ft.Relationship(es["accounts"]["EOS_Acct"],
                                      es["tradelines"]["EOS_Acct"])

# %%
# add the relationship to the entity set
es = es.add_relationship(new_relationship)

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es, target_entity="accounts")

# %%
feature_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9573 entries, 8147057 to 9682285
# Data columns (total 97 columns):
# Client_ID                                            9573 non-null object
# Disposition                                          9573 non-null object
# Dept                                                 9573 non-null float64
# Initial_Balance                                      9573 non-null float64
# Account_Balance                                      9573 non-null float64
# Experian_Score                                       9573 non-null float64
# Sungard_Score                                        9573 non-null object
# Collector_ID                                         9573 non-null object
# Disp_Chg_Date                                        9573 non-null datetime64[ns]
# HSG_Proscore                                         9573 non-null float64
# SUM(tradelines.Term_Duration)                        9573 non-null float64
# SUM(tradelines.History_Reviewed)                     9573 non-null float64
# SUM(tradelines.Delinquent_Payments)                  9573 non-null float64
# SUM(tradelines.Late_30_Days)                         9573 non-null float64
# SUM(tradelines.Late_60_Days)                         9573 non-null float64
# SUM(tradelines.Late_90_Days)                         9573 non-null float64
# STD(tradelines.Term_Duration)                        9288 non-null float64
# STD(tradelines.History_Reviewed)                     9288 non-null float64
# STD(tradelines.Delinquent_Payments)                  9288 non-null float64
# STD(tradelines.Late_30_Days)                         9288 non-null float64
# STD(tradelines.Late_60_Days)                         9288 non-null float64
# STD(tradelines.Late_90_Days)                         9288 non-null float64
# MAX(tradelines.Term_Duration)                        9299 non-null float64
# MAX(tradelines.History_Reviewed)                     9299 non-null float64
# MAX(tradelines.Delinquent_Payments)                  9299 non-null float64
# MAX(tradelines.Late_30_Days)                         9299 non-null float64
# MAX(tradelines.Late_60_Days)                         9299 non-null float64
# MAX(tradelines.Late_90_Days)                         9299 non-null float64
# SKEW(tradelines.Term_Duration)                       9249 non-null float64
# SKEW(tradelines.History_Reviewed)                    9249 non-null float64
# SKEW(tradelines.Delinquent_Payments)                 9249 non-null float64
# SKEW(tradelines.Late_30_Days)                        9249 non-null float64
# SKEW(tradelines.Late_60_Days)                        9249 non-null float64
# SKEW(tradelines.Late_90_Days)                        9249 non-null float64
# MIN(tradelines.Term_Duration)                        9299 non-null float64
# MIN(tradelines.History_Reviewed)                     9299 non-null float64
# MIN(tradelines.Delinquent_Payments)                  9299 non-null float64
# MIN(tradelines.Late_30_Days)                         9299 non-null float64
# MIN(tradelines.Late_60_Days)                         9299 non-null float64
# MIN(tradelines.Late_90_Days)                         9299 non-null float64
# MEAN(tradelines.Term_Duration)                       9299 non-null float64
# MEAN(tradelines.History_Reviewed)                    9299 non-null float64
# MEAN(tradelines.Delinquent_Payments)                 9299 non-null float64
# MEAN(tradelines.Late_30_Days)                        9299 non-null float64
# MEAN(tradelines.Late_60_Days)                        9299 non-null float64
# MEAN(tradelines.Late_90_Days)                        9299 non-null float64
# COUNT(tradelines)                                    9573 non-null float64
# NUM_UNIQUE(tradelines.Responsible)                   9299 non-null float64
# NUM_UNIQUE(tradelines.Tradeline_Type)                9299 non-null float64
# NUM_UNIQUE(tradelines.Subscriber_Code)               9299 non-null float64
# NUM_UNIQUE(tradelines.Industry_Type)                 9299 non-null float64
# NUM_UNIQUE(tradelines.Tradeline_Usage)               9299 non-null float64
# NUM_UNIQUE(tradelines.Trade_Ending_Cd)               9299 non-null float64
# NUM_UNIQUE(tradelines.Manner_Of_Payment)             9299 non-null float64
# NUM_UNIQUE(tradelines.Indicator_Code_1)              9299 non-null float64
# NUM_UNIQUE(tradelines.Subject_Type)                  9299 non-null float64
# MODE(tradelines.Responsible)                         9299 non-null object
# MODE(tradelines.Tradeline_Type)                      9299 non-null object
# MODE(tradelines.Subscriber_Code)                     9299 non-null float64
# MODE(tradelines.Industry_Type)                       9299 non-null object
# MODE(tradelines.Tradeline_Usage)                     9299 non-null object
# MODE(tradelines.Trade_Ending_Cd)                     9299 non-null object
# MODE(tradelines.Manner_Of_Payment)                   9299 non-null object
# MODE(tradelines.Indicator_Code_1)                    9299 non-null object
# MODE(tradelines.Subject_Type)                        9299 non-null object
# DAY(List_Date)                                       9573 non-null int64
# DAY(FACS_Load_Date)                                  9573 non-null int64
# YEAR(List_Date)                                      9573 non-null int64
# YEAR(FACS_Load_Date)                                 9573 non-null int64
# MONTH(List_Date)                                     9573 non-null int64
# MONTH(FACS_Load_Date)                                9573 non-null int64
# WEEKDAY(List_Date)                                   9573 non-null int64
# WEEKDAY(FACS_Load_Date)                              9573 non-null int64
# NUM_UNIQUE(tradelines.DAY(Date_Reported))            9299 non-null float64
# NUM_UNIQUE(tradelines.DAY(Date_Opened))              9299 non-null float64
# NUM_UNIQUE(tradelines.DAY(Manner_Of_Pmt_Dte))        9299 non-null float64
# NUM_UNIQUE(tradelines.YEAR(Date_Reported))           9299 non-null float64
# NUM_UNIQUE(tradelines.YEAR(Date_Opened))             9299 non-null float64
# NUM_UNIQUE(tradelines.YEAR(Manner_Of_Pmt_Dte))       9299 non-null float64
# NUM_UNIQUE(tradelines.MONTH(Date_Reported))          9299 non-null float64
# NUM_UNIQUE(tradelines.MONTH(Date_Opened))            9299 non-null float64
# NUM_UNIQUE(tradelines.MONTH(Manner_Of_Pmt_Dte))      9299 non-null float64
# NUM_UNIQUE(tradelines.WEEKDAY(Date_Reported))        9299 non-null float64
# NUM_UNIQUE(tradelines.WEEKDAY(Date_Opened))          9299 non-null float64
# NUM_UNIQUE(tradelines.WEEKDAY(Manner_Of_Pmt_Dte))    9299 non-null float64
# MODE(tradelines.DAY(Date_Reported))                  9299 non-null float64
# MODE(tradelines.DAY(Date_Opened))                    9299 non-null float64
# MODE(tradelines.DAY(Manner_Of_Pmt_Dte))              9299 non-null float64
# MODE(tradelines.YEAR(Date_Reported))                 9299 non-null float64
# MODE(tradelines.YEAR(Date_Opened))                   9299 non-null float64
# MODE(tradelines.YEAR(Manner_Of_Pmt_Dte))             9299 non-null float64
# MODE(tradelines.MONTH(Date_Reported))                9299 non-null float64
# MODE(tradelines.MONTH(Date_Opened))                  9299 non-null float64
# MODE(tradelines.MONTH(Manner_Of_Pmt_Dte))            9299 non-null float64
# MODE(tradelines.WEEKDAY(Date_Reported))              9299 non-null float64
# MODE(tradelines.WEEKDAY(Date_Opened))                9299 non-null float64
# MODE(tradelines.WEEKDAY(Manner_Of_Pmt_Dte))          9299 non-null float64
# dtypes: datetime64[ns](1), float64(76), int64(8), object(12)
# memory usage: 7.2+ MB
