# %% [markdown]
# # Data Wrangling Using Pandas : Transform Data

# %% [markdown]
# ## Goal: Prepare the data to better expose the underlying data patterns to Machine Learning algorithms.
#
# We will use Pandas, a tool for data manipulation, munging and analysis of tabular and time series data. Explore the data to gain insight. It contains extensive tools designed to make data analysis fast and easy.  https://pandas.pydata.org/pandas-docs/stable/dsintro.html
#
# Let's use these tools to tidy our data and prepare it for binary classification task.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import missingno as msno # explore missing data
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import Imputer

# %% [markdown]
# # Transformations

# %% [markdown]
# ## Determine Amount of Missing Data

# %%
# Count the number of nulls in each colums
df.isnull().sum().sort_values()
# Out:
# SK_ID_CURR                      0
# SK_ID_BUREAU                    0
# CREDIT_ACTIVE                   0
# CREDIT_CURRENCY                 0
# DAYS_CREDIT                     0
# CREDIT_DAY_OVERDUE              0
# DAYS_CREDIT_UPDATE              0
# CNT_CREDIT_PROLONG              0
# AMT_CREDIT_SUM_OVERDUE          0
# CREDIT_TYPE                     0
# AMT_CREDIT_SUM                 13
# DAYS_CREDIT_ENDDATE        105553
# AMT_CREDIT_SUM_DEBT        257669
# AMT_CREDIT_SUM_LIMIT       591780
# DAYS_ENDDATE_FACT          633653
# AMT_CREDIT_MAX_OVERDUE    1124488
# AMT_ANNUITY               1226791
# dtype: int64

# %% [markdown]
# ## Drop Columns to Handle missing Data

# %%
# Drop columns containing "too many" nulls
df.dropna(axis='columns', thresh=1716428 - 1124488, inplace=True)
msno.bar(df)
# Out:
# Threshold  591940

# %% [markdown]
# ## Impute Values to handle missing Data

# %%
# Replace missing data with a special value. Missing information captured in the model
df.fillna(999,inplace=False).head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0              999.0
# 2                   0                528.0              999.0
# 3                   0                999.0              999.0
# 4                   0               1197.0              999.0
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                   999.0                   0         91323.0
# 1                   999.0                   0        225000.0
# 2                   999.0                   0        464323.5
# 3                   999.0                   0         90000.0
# 4                 77674.5                   0       2700000.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                 999.0                     0.0
# 1             171342.0                 999.0                     0.0
# 2                999.0                 999.0                     0.0
# 3                999.0                 999.0                     0.0
# 4                999.0                 999.0                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 0  Consumer credit                -131        999.0
# 1      Credit card                 -20        999.0
# 2  Consumer credit                 -16        999.0
# 3      Credit card                 -16        999.0
# 4  Consumer credit                 -21        999.0

# %% [markdown]
# ## Remove Outliers

# %%
df.DAYS_CREDIT.clip(lower=-2000,upper=-500).hist()

# %%
df.values_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7564d357447> in <module>()
# ----> 1 df.values_counts()
#
# NameError: name 'df' is not defined
